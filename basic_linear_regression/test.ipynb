# %%
import pandas as pd
import matplotlib.pyplot as plt
from linear_regression import LinearRegression
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

df = pd.read_csv("example.csv",sep = ";")

df
# Out:
#    alan  odasayisi  binayasi   fiyat
# 0   180          5        10  510000
# 1   225          4        18  508000
# 2   260          3         2  548000
# 3   320          6        10  650000
# 4   335          4         9  628000
# 5   345          5        14  632000
# 6   355          3         0  680000
# 7   400          4        10  725000

# %%
y = df["fiyat"].values

x = df.drop(["fiyat"],axis=1).values

x = sc.fit_transform(x)

model = LinearRegression(lr = 0.1,iter = 100)

model.fit(x,y)

plt.plot(model.loss_list)
plt.show()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 45447.00it/s]
# loss = 377850125000.0 , w = [14424.97156803  -161.37430609 -4342.33239944] , b = 122025.0
# loss = 269667138.76931846 , w = [ 69834.3277382   13168.23760764 -13353.85268457] , b = 604497.590136014
# loss = 218084016.01428455 , w = [ 70483.24200686  14257.26029501 -14076.84577592] , b = 610060.1203815257
# loss = 218049964.81125948 , w = [ 70466.23068513  14394.06231566 -14215.42923937] , b = 610124.2519889266
# loss = 218049190.51409203 , w = [ 70461.31391199  14416.3707597  -14239.08882483] , b = 610124.9913760194

# %%
y_pred = model.predict(x)

plt.plot(y)

plt.plot(y_pred)

plt.show()
